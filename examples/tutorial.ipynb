# %% [markdown]
# # Tutorial

# %% [markdown]
# ## Getting and manipulating the meta data

# %%
import fstpy.all as fstpy
import pathlib
from datetime import datetime
import numpy as np
import pandas as pd

# %% [markdown]
# ### method 1 - to_pandas with explicit instance

# %%
std_file = fstpy.StandardFileReader('/fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_5005.std')
df = std_file.to_pandas()
# remove d to display otherwise its slow
cols = list(df.columns)
cols.remove('d')
df[cols].head(10)
# Out:
#   nomvar typvar     etiket    ni    nj  nk      dateo       ip1  ip2  ip3  \
# 0     HU      P  R1_V710_N  1108  1082   1  442998800  95529009    6    0
# 1     HU      P  R1_V710_N  1108  1082   1  442998800  97351772    6    0
# 2     GZ      P  R1_V710_N  1108  1082   1  442998800  95364364    6    0
# 3     GZ      P  R1_V710_N  1108  1082   1  442998800  95357866    6    0
# 4     TT      P  R1_V710_N  1108  1082   1  442998800  95178882    6    0
# 5     TT      P  R1_V710_N  1108  1082   1  442998800  95154915    6    0
# 6     HR      P  R1_V710_N  1108  1082   1  442998800  94803839    6    0
# 7     HR      P  R1_V710_N  1108  1082   1  442998800  94779089    6    0
# 8     WE      P  R1_V710_N  1108  1082   1  442998800  94565237    6    0
# 9     WE      P  R1_V710_N  1108  1082   1  442998800  94553255    6    0
#
#    ...    ig1    ig2  ig3  ig4      datev   key  \
# 0  ...  33792  77761    1    0  443004200     1
# 1  ...  33792  77761    1    0  443004200  1025
# 2  ...  33792  77761    1    0  443004200  2049
# 3  ...  33792  77761    1    0  443004200  3073
# 4  ...  33792  77761    1    0  443004200  4097
# 5  ...  33792  77761    1    0  443004200  5121
# 6  ...  33792  77761    1    0  443004200  6145
# 7  ...  33792  77761    1    0  443004200  7169
# 8  ...  33792  77761    1    0  443004200  8193
# 9  ...  33792  77761    1    0  443004200  9217
#
#                                                 path  file_modification_time  \
# 0  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 1  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 2  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 3  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 4  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 5  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 6  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 7  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 8  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 9  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
#
#           shape        grid
# 0  (1108, 1082)  3379277761
# 1  (1108, 1082)  3379277761
# 2  (1108, 1082)  3379277761
# 3  (1108, 1082)  3379277761
# 4  (1108, 1082)  3379277761
# 5  (1108, 1082)  3379277761
# 6  (1108, 1082)  3379277761
# 7  (1108, 1082)  3379277761
# 8  (1108, 1082)  3379277761
# 9  (1108, 1082)  3379277761
#
# [10 rows x 25 columns]

# %% [markdown]
# ### method 2 - to_pandas without explicit instance

# %%
df = fstpy.StandardFileReader('/fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_5005.std').to_pandas()
# remove d to display otherwise its slow
cols = list(df.columns)
cols.remove('d')
df[cols].head(10)
# Out:
#   nomvar typvar     etiket    ni    nj  nk      dateo       ip1  ip2  ip3  \
# 0     HU      P  R1_V710_N  1108  1082   1  442998800  95529009    6    0
# 1     HU      P  R1_V710_N  1108  1082   1  442998800  97351772    6    0
# 2     GZ      P  R1_V710_N  1108  1082   1  442998800  95364364    6    0
# 3     GZ      P  R1_V710_N  1108  1082   1  442998800  95357866    6    0
# 4     TT      P  R1_V710_N  1108  1082   1  442998800  95178882    6    0
# 5     TT      P  R1_V710_N  1108  1082   1  442998800  95154915    6    0
# 6     HR      P  R1_V710_N  1108  1082   1  442998800  94803839    6    0
# 7     HR      P  R1_V710_N  1108  1082   1  442998800  94779089    6    0
# 8     WE      P  R1_V710_N  1108  1082   1  442998800  94565237    6    0
# 9     WE      P  R1_V710_N  1108  1082   1  442998800  94553255    6    0
#
#    ...    ig1    ig2  ig3  ig4      datev   key  \
# 0  ...  33792  77761    1    0  443004200     1
# 1  ...  33792  77761    1    0  443004200  1025
# 2  ...  33792  77761    1    0  443004200  2049
# 3  ...  33792  77761    1    0  443004200  3073
# 4  ...  33792  77761    1    0  443004200  4097
# 5  ...  33792  77761    1    0  443004200  5121
# 6  ...  33792  77761    1    0  443004200  6145
# 7  ...  33792  77761    1    0  443004200  7169
# 8  ...  33792  77761    1    0  443004200  8193
# 9  ...  33792  77761    1    0  443004200  9217
#
#                                                 path  file_modification_time  \
# 0  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 1  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 2  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 3  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 4  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 5  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 6  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 7  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 8  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
# 9  /fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_...     2021-01-26 09:31:54
#
#           shape        grid
# 0  (1108, 1082)  3379277761
# 1  (1108, 1082)  3379277761
# 2  (1108, 1082)  3379277761
# 3  (1108, 1082)  3379277761
# 4  (1108, 1082)  3379277761
# 5  (1108, 1082)  3379277761
# 6  (1108, 1082)  3379277761
# 7  (1108, 1082)  3379277761
# 8  (1108, 1082)  3379277761
# 9  (1108, 1082)  3379277761
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Get a dataframe from multiple standard files

# %%
# get files from today
dateTimeObj = datetime.now()
timestamp = dateTimeObj.strftime("%Y%m%d")# (%H:%M:%S.%f)")
timestamp = ''.join([timestamp,'00'])

RDPS_PATH = pathlib.Path('/fs/site3/eccc/ops/cmod/prod/hubs/suites/ops/rdps_20191231/r1/gridpt.usr/prog/eta')
rdps_files = [f for f in RDPS_PATH.iterdir() if f.name.startswith(timestamp)]

# split the results
files = np.array_split(np.array(rdps_files),4)

df = fstpy.StandardFileReader(list(files[0]),decode_metadata=True).to_pandas()
cols = list(df.columns)
cols.remove('d')
# Out:
# WARNING:root:Found duplicate rows in dataframe!

# %% [markdown]
# ### See the contents of the dataframe

# %% [markdown]
# #### show the last rows of the dataframe

# %%
df[cols].tail(10)
# Out:
#       nomvar typvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3  \
# 26698     J8      P  R1_V710_N  1102  1076   1  452535200  1196   54    0
# 26699     J8      P  R1_V710_N  1102  1076   1  452535200  1197   54    0
# 26700     J8      P  R1_V710_N  1102  1076   1  452535200  1195   54    0
# 26701     J8      P  R1_V710_N  1102  1076   1  452535200  1198   54    0
# 26702     J8      P  R1_V710_N  1102  1076   1  452535200  1199   54    0
# 26703     K1      P  R1_V710_N  1102  1076   1  452535200  1195   54    0
# 26704     K1      P  R1_V710_N  1102  1076   1  452535200  1196   54    0
# 26705     K1      P  R1_V710_N  1102  1076   1  452535200  1197   54    0
# 26706     K1      P  R1_V710_N  1102  1076   1  452535200  1198   54    0
# 26707     K1      P  R1_V710_N  1102  1076   1  452535200  1199   54    0
#
#        ...  interval  multiple_modifications  zapped  filtered interpolated  \
# 26698  ...      None                   False   False     False        False
# 26699  ...      None                   False   False     False        False
# 26700  ...      None                   False   False     False        False
# 26701  ...      None                   False   False     False        False
# 26702  ...      None                   False   False     False        False
# 26703  ...      None                   False   False     False        False
# 26704  ...      None                   False   False     False        False
# 26705  ...      None                   False   False     False        False
# 26706  ...      None                   False   False     False        False
# 26707  ...      None                   False   False     False        False
#
#        unit_converted  bounded  missing_data  ensemble_extra_info   vctype
# 26698           False    False         False                False  UNKNOWN
# 26699           False    False         False                False  UNKNOWN
# 26700           False    False         False                False  UNKNOWN
# 26701           False    False         False                False  UNKNOWN
# 26702           False    False         False                False  UNKNOWN
# 26703           False    False         False                False  UNKNOWN
# 26704           False    False         False                False  UNKNOWN
# 26705           False    False         False                False  UNKNOWN
# 26706           False    False         False                False  UNKNOWN
# 26707           False    False         False                False  UNKNOWN
#
# [10 rows x 57 columns]

# %% [markdown]
# #### show column names of the dataframe

# %%
df.columns
# Out:
# Index(['nomvar', 'typvar', 'etiket', 'ni', 'nj', 'nk', 'dateo', 'ip1', 'ip2',
#        'ip3', 'deet', 'npas', 'datyp', 'nbits', 'grtyp', 'ig1', 'ig2', 'ig3',
#        'ig4', 'datev', 'key', 'path', 'file_modification_time', 'shape',
#        'grid', 'd', 'label', 'run', 'implementation', 'ensemble_member',
#        'unit', 'description', 'date_of_observation', 'date_of_validity',
#        'forecast_hour', 'data_type_str', 'level', 'ip1_kind', 'ip1_pkind',
#        'ip2_dec', 'ip2_kind', 'ip2_pkind', 'ip3_dec', 'ip3_kind', 'ip3_pkind',
#        'surface', 'follow_topography', 'ascending', 'interval',
#        'multiple_modifications', 'zapped', 'filtered', 'interpolated',
#        'unit_converted', 'bounded', 'missing_data', 'ensemble_extra_info',
#        'vctype'],
#       dtype='object')

# %% [markdown]
# #### show the levels contained in the dataframe

# %%
df.level
# Out:
# 0        0.0000
# 1        0.0000
# 44       0.0000
# 45       0.0102
# 46       0.0233
#           ...
# 26703    5.0000
# 26704    4.0000
# 26705    3.0000
# 26706    2.0000
# 26707    1.0000
# Name: level, Length: 26666, dtype: float32

# %%
#### show the unique levels contained in the dataframe

# %%
df.level.unique()
# Out:
# array([0.    , 0.0102, 0.0233, 0.0374, 0.0508, 0.0625, 0.072 , 0.0795,
#        0.0852, 0.0897, 0.0941, 0.099 , 0.1044, 0.1104, 0.1172, 0.1248,
#        0.1334, 0.1431, 0.1541, 0.1667, 0.1812, 0.1976, 0.2149, 0.2331,
#        0.2522, 0.2721, 0.2928, 0.3144, 0.3369, 0.3602, 0.3843, 0.4091,
#        0.4348, 0.4612, 0.4883, 0.5161, 0.5446, 0.5737, 0.6034, 0.6337,
#        0.6646, 0.6959, 0.7272, 0.7567, 0.7845, 0.8104, 0.8346, 0.8571,
#        0.878 , 0.8973, 0.9151, 0.9316, 0.9467, 0.9606, 0.967 , 0.9733,
#        0.9792, 0.985 , 0.99  , 0.995 , 0.9975, 1.    , 5.    , 4.    ,
#        3.    , 2.    ], dtype=float32)

# %% [markdown]
# #### show a subset of columns of the dataframe

# %%
df[['nomvar','typvar','etiket','ni','nj','nk','dateo','ip1','ip2','ip3']]
# Out:
#       nomvar typvar     etiket    ni    nj  nk      dateo    ip1    ip2  ip3
# 0         >>      X  R1_V710_N  1102     1   1  408244400  86086  77806    1
# 1         ^^      X  R1_V710_N     1  1076   1  408244400  86086  77806    1
# 44        TT      P  R1_V710_N  1102  1076   1  452535200   2000     68    0
# 45        TT      P  R1_V710_N  1102  1076   1  452535200   2102     68    0
# 46        TT      P  R1_V710_N  1102  1076   1  452535200   2233     68    0
# ...      ...    ...        ...   ...   ...  ..        ...    ...    ...  ...
# 26703     K1      P  R1_V710_N  1102  1076   1  452535200   1195     54    0
# 26704     K1      P  R1_V710_N  1102  1076   1  452535200   1196     54    0
# 26705     K1      P  R1_V710_N  1102  1076   1  452535200   1197     54    0
# 26706     K1      P  R1_V710_N  1102  1076   1  452535200   1198     54    0
# 26707     K1      P  R1_V710_N  1102  1076   1  452535200   1199     54    0
#
# [26666 rows x 10 columns]

# %% [markdown]
# #### show a voir like output of the dataframe

# %%
fstpy.voir(df.head(10))
# Out:
#   nomvar typvar     etiket    ni    nj  nk               dateo    ip1    ip2  ip3  deet  npas datyp  nbits grtyp    ig1    ig2    ig3    ig4
# 0     >>      X  R1_V710_N  1102     1   1 2016-02-17 12:00:00  86086  77806    1     0     0     E     32     E   1470    560  54400  46560
# 1     TT      P  R1_V710_N  1102  1076   1 2021-09-29 00:00:00   2795     68    0   300   816     f     16     Z  86086  77806      1      0
# 2     TT      P  R1_V710_N  1102  1076   1 2021-09-29 00:00:00   2720     68    0   300   816     f     16     Z  86086  77806      1      0
# 3     TT      P  R1_V710_N  1102  1076   1 2021-09-29 00:00:00   2625     68    0   300   816     f     16     Z  86086  77806      1      0
# 4     TT      P  R1_V710_N  1102  1076   1 2021-09-29 00:00:00   2508     68    0   300   816     f     16     Z  86086  77806      1      0
# 5     TT      P  R1_V710_N  1102  1076   1 2021-09-29 00:00:00   2374     68    0   300   816     f     16     Z  86086  77806      1      0
# 6     TT      P  R1_V710_N  1102  1076   1 2021-09-29 00:00:00   2233     68    0   300   816     f     16     Z  86086  77806      1      0
# 7     TT      P  R1_V710_N  1102  1076   1 2021-09-29 00:00:00   2102     68    0   300   816     f     16     Z  86086  77806      1      0
# 8     TT      P  R1_V710_N  1102  1076   1 2021-09-29 00:00:00   2000     68    0   300   816     f     16     Z  86086  77806      1      0
# 9     ^^      X  R1_V710_N     1  1076   1 2016-02-17 12:00:00  86086  77806    1     0     0     E     32     E   1470    560  54400  46560

# %% [markdown]
# ### select sub-sets of data

# %% [markdown]
# #### select TT

# %%
sel_tt_df = df.query('nomvar=="TT"')
sel_tt_df.head(10)
# Out:
#    nomvar typvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3  ...  \
# 44     TT      P  R1_V710_N  1102  1076   1  452535200  2000   68    0  ...
# 45     TT      P  R1_V710_N  1102  1076   1  452535200  2102   68    0  ...
# 46     TT      P  R1_V710_N  1102  1076   1  452535200  2233   68    0  ...
# 47     TT      P  R1_V710_N  1102  1076   1  452535200  2374   68    0  ...
# 48     TT      P  R1_V710_N  1102  1076   1  452535200  2508   68    0  ...
# 49     TT      P  R1_V710_N  1102  1076   1  452535200  2625   68    0  ...
# 50     TT      P  R1_V710_N  1102  1076   1  452535200  2720   68    0  ...
# 51     TT      P  R1_V710_N  1102  1076   1  452535200  2795   68    0  ...
# 52     TT      P  R1_V710_N  1102  1076   1  452535200  2852   68    0  ...
# 53     TT      P  R1_V710_N  1102  1076   1  452535200  2897   68    0  ...
#
#     interval  multiple_modifications  zapped  filtered interpolated  \
# 44      None                   False   False     False        False
# 45      None                   False   False     False        False
# 46      None                   False   False     False        False
# 47      None                   False   False     False        False
# 48      None                   False   False     False        False
# 49      None                   False   False     False        False
# 50      None                   False   False     False        False
# 51      None                   False   False     False        False
# 52      None                   False   False     False        False
# 53      None                   False   False     False        False
#
#     unit_converted  bounded  missing_data  ensemble_extra_info  vctype
# 44           False    False         False                False     ETA
# 45           False    False         False                False     ETA
# 46           False    False         False                False     ETA
# 47           False    False         False                False     ETA
# 48           False    False         False                False     ETA
# 49           False    False         False                False     ETA
# 50           False    False         False                False     ETA
# 51           False    False         False                False     ETA
# 52           False    False         False                False     ETA
# 53           False    False         False                False     ETA
#
# [10 rows x 58 columns]

# %% [markdown]
# #### or

# %%
sel_tt_df = df.loc[df.nomvar=="TT"]
sel_tt_df.head(10)
# Out:
#    nomvar typvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3  ...  \
# 44     TT      P  R1_V710_N  1102  1076   1  452535200  2000   68    0  ...
# 45     TT      P  R1_V710_N  1102  1076   1  452535200  2102   68    0  ...
# 46     TT      P  R1_V710_N  1102  1076   1  452535200  2233   68    0  ...
# 47     TT      P  R1_V710_N  1102  1076   1  452535200  2374   68    0  ...
# 48     TT      P  R1_V710_N  1102  1076   1  452535200  2508   68    0  ...
# 49     TT      P  R1_V710_N  1102  1076   1  452535200  2625   68    0  ...
# 50     TT      P  R1_V710_N  1102  1076   1  452535200  2720   68    0  ...
# 51     TT      P  R1_V710_N  1102  1076   1  452535200  2795   68    0  ...
# 52     TT      P  R1_V710_N  1102  1076   1  452535200  2852   68    0  ...
# 53     TT      P  R1_V710_N  1102  1076   1  452535200  2897   68    0  ...
#
#     interval  multiple_modifications  zapped  filtered interpolated  \
# 44      None                   False   False     False        False
# 45      None                   False   False     False        False
# 46      None                   False   False     False        False
# 47      None                   False   False     False        False
# 48      None                   False   False     False        False
# 49      None                   False   False     False        False
# 50      None                   False   False     False        False
# 51      None                   False   False     False        False
# 52      None                   False   False     False        False
# 53      None                   False   False     False        False
#
#     unit_converted  bounded  missing_data  ensemble_extra_info  vctype
# 44           False    False         False                False     ETA
# 45           False    False         False                False     ETA
# 46           False    False         False                False     ETA
# 47           False    False         False                False     ETA
# 48           False    False         False                False     ETA
# 49           False    False         False                False     ETA
# 50           False    False         False                False     ETA
# 51           False    False         False                False     ETA
# 52           False    False         False                False     ETA
# 53           False    False         False                False     ETA
#
# [10 rows x 58 columns]

# %% [markdown]
# #### select multiple fields

# %%
sel_uuvv_df = df.loc[df.nomvar.isin(["UU","VV"])]
sel_uuvv_df.head(10)
# Out:
#     nomvar typvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3  ...  \
# 354     UU      P  R1_V710_N  1102  1076   1  452535200  2000   68    0  ...
# 355     UU      P  R1_V710_N  1102  1076   1  452535200  2102   68    0  ...
# 356     UU      P  R1_V710_N  1102  1076   1  452535200  2233   68    0  ...
# 357     UU      P  R1_V710_N  1102  1076   1  452535200  2374   68    0  ...
# 358     UU      P  R1_V710_N  1102  1076   1  452535200  2508   68    0  ...
# 359     UU      P  R1_V710_N  1102  1076   1  452535200  2625   68    0  ...
# 360     UU      P  R1_V710_N  1102  1076   1  452535200  2720   68    0  ...
# 361     UU      P  R1_V710_N  1102  1076   1  452535200  2795   68    0  ...
# 362     UU      P  R1_V710_N  1102  1076   1  452535200  2852   68    0  ...
# 363     UU      P  R1_V710_N  1102  1076   1  452535200  2897   68    0  ...
#
#      interval  multiple_modifications  zapped  filtered interpolated  \
# 354      None                   False   False     False        False
# 355      None                   False   False     False        False
# 356      None                   False   False     False        False
# 357      None                   False   False     False        False
# 358      None                   False   False     False        False
# 359      None                   False   False     False        False
# 360      None                   False   False     False        False
# 361      None                   False   False     False        False
# 362      None                   False   False     False        False
# 363      None                   False   False     False        False
#
#      unit_converted  bounded  missing_data  ensemble_extra_info  vctype
# 354           False    False         False                False     ETA
# 355           False    False         False                False     ETA
# 356           False    False         False                False     ETA
# 357           False    False         False                False     ETA
# 358           False    False         False                False     ETA
# 359           False    False         False                False     ETA
# 360           False    False         False                False     ETA
# 361           False    False         False                False     ETA
# 362           False    False         False                False     ETA
# 363           False    False         False                False     ETA
#
# [10 rows x 58 columns]

# %% [markdown]
# #### select multiple fields with more than one condition

# %%
sel_uuvv6_df = df.loc[(df.nomvar.isin(["UU","VV"])) & (df.ip2==6)]
sel_uuvv6_df.tail(10)
# Out:
# Empty DataFrame
# Columns: [nomvar, typvar, etiket, ni, nj, nk, dateo, ip1, ip2, ip3, deet, npas, datyp, nbits, grtyp, ig1, ig2, ig3, ig4, datev, key, path, file_modification_time, shape, grid, d, label, run, implementation, ensemble_member, unit, description, date_of_observation, date_of_validity, forecast_hour, data_type_str, level, ip1_kind, ip1_pkind, ip2_dec, ip2_kind, ip2_pkind, ip3_dec, ip3_kind, ip3_pkind, surface, follow_topography, ascending, interval, multiple_modifications, zapped, filtered, interpolated, unit_converted, bounded, missing_data, ensemble_extra_info, vctype]
# Index: []
#
# [0 rows x 58 columns]

# %% [markdown]
# #### selecting by date range

# %%
# define a start and end date
start_date = datetime(dateTimeObj.year,dateTimeObj.month,dateTimeObj.day)
end_date = datetime(dateTimeObj.year,dateTimeObj.month,dateTimeObj.day+1,23)

df.loc[df.date_of_validity.between(start_date, end_date, inclusive=True)]
# Out:
#       nomvar typvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3  \
# 1099      TT      P  R1_V710_N  1102  1076   1  452535200  2000   32    0
# 1100      TT      P  R1_V710_N  1102  1076   1  452535200  2102   32    0
# 1101      TT      P  R1_V710_N  1102  1076   1  452535200  2233   32    0
# 1102      TT      P  R1_V710_N  1102  1076   1  452535200  2374   32    0
# 1103      TT      P  R1_V710_N  1102  1076   1  452535200  2508   32    0
# ...      ...    ...        ...   ...   ...  ..        ...   ...  ...  ...
# 26644     K1      P  R1_V710_N  1102  1076   1  452535200  1195   31    0
# 26645     K1      P  R1_V710_N  1102  1076   1  452535200  1196   31    0
# 26646     K1      P  R1_V710_N  1102  1076   1  452535200  1197   31    0
# 26647     K1      P  R1_V710_N  1102  1076   1  452535200  1198   31    0
# 26648     K1      P  R1_V710_N  1102  1076   1  452535200  1199   31    0
#
#        ...  interval  multiple_modifications  zapped  filtered interpolated  \
# 1099   ...      None                   False   False     False        False
# 1100   ...      None                   False   False     False        False
# 1101   ...      None                   False   False     False        False
# 1102   ...      None                   False   False     False        False
# 1103   ...      None                   False   False     False        False
# ...    ...       ...                     ...     ...       ...          ...
# 26644  ...      None                   False   False     False        False
# 26645  ...      None                   False   False     False        False
# 26646  ...      None                   False   False     False        False
# 26647  ...      None                   False   False     False        False
# 26648  ...      None                   False   False     False        False
#
#        unit_converted  bounded  missing_data  ensemble_extra_info   vctype
# 1099            False    False         False                False      ETA
# 1100            False    False         False                False      ETA
# 1101            False    False         False                False      ETA
# 1102            False    False         False                False      ETA
# 1103            False    False         False                False      ETA
# ...               ...      ...           ...                  ...      ...
# 26644           False    False         False                False  UNKNOWN
# 26645           False    False         False                False  UNKNOWN
# 26646           False    False         False                False  UNKNOWN
# 26647           False    False         False                False  UNKNOWN
# 26648           False    False         False                False  UNKNOWN
#
# [13332 rows x 58 columns]

# %% [markdown]
# ### Modify meta data

# %% [markdown]
# #### change nomvar from TT to TTI

# %%
df.loc[df.nomvar=='TT','nomvar'] = 'TTI'
print(df.loc[df.nomvar=='TTI'])
# rename again
df.loc[df.nomvar=='TTI','nomvar'] = 'TT'
# Out:
#       nomvar typvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3  \
# 44       TTI      P  R1_V710_N  1102  1076   1  452535200   2000   68    0
# 45       TTI      P  R1_V710_N  1102  1076   1  452535200   2102   68    0
# 46       TTI      P  R1_V710_N  1102  1076   1  452535200   2233   68    0
# 47       TTI      P  R1_V710_N  1102  1076   1  452535200   2374   68    0
# 48       TTI      P  R1_V710_N  1102  1076   1  452535200   2508   68    0
# ...      ...    ...        ...   ...   ...  ..        ...    ...  ...  ...
# 22256    TTI      P  R1_V710_N  1102  1076   1  452535200  11850   54    0
# 22257    TTI      P  R1_V710_N  1102  1076   1  452535200  11900   54    0
# 22258    TTI      P  R1_V710_N  1102  1076   1  452535200  11950   54    0
# 22259    TTI      P  R1_V710_N  1102  1076   1  452535200  11975   54    0
# 22260    TTI      P  R1_V710_N  1102  1076   1  452535200  12000   54    0
#
#        ...  interval  multiple_modifications  zapped  filtered interpolated  \
# 44     ...      None                   False   False     False        False
# 45     ...      None                   False   False     False        False
# 46     ...      None                   False   False     False        False
# 47     ...      None                   False   False     False        False
# 48     ...      None                   False   False     False        False
# ...    ...       ...                     ...     ...       ...          ...
# 22256  ...      None                   False   False     False        False
# 22257  ...      None                   False   False     False        False
# 22258  ...      None                   False   False     False        False
# 22259  ...      None                   False   False     False        False
# 22260  ...      None                   False   False     False        False
#
#        unit_converted  bounded  missing_data  ensemble_extra_info  vctype
# 44              False    False         False                False     ETA
# 45              False    False         False                False     ETA
# 46              False    False         False                False     ETA
# 47              False    False         False                False     ETA
# 48              False    False         False                False     ETA
# ...               ...      ...           ...                  ...     ...
# 22256           False    False         False                False     ETA
# 22257           False    False         False                False     ETA
# 22258           False    False         False                False     ETA
# 22259           False    False         False                False     ETA
# 22260           False    False         False                False     ETA
#
# [1364 rows x 58 columns]

# %% [markdown]
# ### Reformatting meta data for other types or structures

# %% [markdown]
# #### changind the column names

# %%
translation = {'nomvar':'fieldName','etiket':'pdsLabel','dateo':'dateOfObservation'}
new_df = df.rename(columns=translation)
cols = list(new_df.columns)
cols.remove('d')
new_df[cols]
# Out:
#       fieldName typvar   pdsLabel    ni    nj  nk  dateOfObservation    ip1  \
# 0            >>      X  R1_V710_N  1102     1   1          408244400  86086
# 1            ^^      X  R1_V710_N     1  1076   1          408244400  86086
# 44           TT      P  R1_V710_N  1102  1076   1          452535200   2000
# 45           TT      P  R1_V710_N  1102  1076   1          452535200   2102
# 46           TT      P  R1_V710_N  1102  1076   1          452535200   2233
# ...         ...    ...        ...   ...   ...  ..                ...    ...
# 26703        K1      P  R1_V710_N  1102  1076   1          452535200   1195
# 26704        K1      P  R1_V710_N  1102  1076   1          452535200   1196
# 26705        K1      P  R1_V710_N  1102  1076   1          452535200   1197
# 26706        K1      P  R1_V710_N  1102  1076   1          452535200   1198
# 26707        K1      P  R1_V710_N  1102  1076   1          452535200   1199
#
#          ip2  ip3  ...  interval  multiple_modifications  zapped  filtered  \
# 0      77806    1  ...      None                   False   False     False
# 1      77806    1  ...      None                   False   False     False
# 44        68    0  ...      None                   False   False     False
# 45        68    0  ...      None                   False   False     False
# 46        68    0  ...      None                   False   False     False
# ...      ...  ...  ...       ...                     ...     ...       ...
# 26703     54    0  ...      None                   False   False     False
# 26704     54    0  ...      None                   False   False     False
# 26705     54    0  ...      None                   False   False     False
# 26706     54    0  ...      None                   False   False     False
# 26707     54    0  ...      None                   False   False     False
#
#       interpolated  unit_converted  bounded  missing_data  \
# 0            False           False    False         False
# 1            False           False    False         False
# 44           False           False    False         False
# 45           False           False    False         False
# 46           False           False    False         False
# ...            ...             ...      ...           ...
# 26703        False           False    False         False
# 26704        False           False    False         False
# 26705        False           False    False         False
# 26706        False           False    False         False
# 26707        False           False    False         False
#
#        ensemble_extra_info   vctype
# 0                    False  UNKNOWN
# 1                    False  UNKNOWN
# 44                   False      ETA
# 45                   False      ETA
# 46                   False      ETA
# ...                    ...      ...
# 26703                False  UNKNOWN
# 26704                False  UNKNOWN
# 26705                False  UNKNOWN
# 26706                False  UNKNOWN
# 26707                False  UNKNOWN
#
# [26666 rows x 57 columns]

# %% [markdown]
# ## Working with data

# %% [markdown]
# ### Getting the associated data for each record in the dataframe

# %%
uu_df = df.loc[(df.nomvar=="UU") & (df.surface==True)]
vv_df = df.loc[(df.nomvar=="VV") & (df.surface==True)]

uu_data_df = fstpy.compute(uu_df)

cols = ['nomvar','ni','nj','nk','dateo','ip1','ip2','ip3','d']

print(uu_data_df[cols])
# Out:
#       nomvar    ni    nj  nk      dateo    ip1  ip2  ip3  \
# 415       UU  1102  1076   1  452535200  12000   68    0
# 1470      UU  1102  1076   1  452535200  12000   32    0
# 2525      UU  1102  1076   1  452535200  12000   49    0
# 3580      UU  1102  1076   1  452535200  12000   55    0
# 4635      UU  1102  1076   1  452535200  12000   35    0
# 5690      UU  1102  1076   1  452535200  12000   14    0
# 6745      UU  1102  1076   1  452535200  12000   46    0
# 7800      UU  1102  1076   1  452535200  12000   23    0
# 8855      UU  1102  1076   1  452535200  12000   84    0
# 9910      UU  1102  1076   1  452535200  12000   16    0
# 10965     UU  1102  1076   1  452535200  12000   52    0
# 12020     UU  1102  1076   1  452535200  12000   17    0
# 13075     UU  1102  1076   1  452535200  12000   25    0
# 14130     UU  1102  1076   1  452535200  12000   80    0
# 15185     UU  1102  1076   1  452535200  12000   71    0
# 16240     UU  1102  1076   1  452535200  12000   67    0
# 17295     UU  1102  1076   1  452535200  12000   83    0
# 18350     UU  1102  1076   1  452535200  12000    4    0
# 19405     UU  1102  1076   1  452535200  12000   12    0
# 20460     UU  1102  1076   1  452535200  12000   62    0
# 21515     UU  1102  1076   1  452535200  12000   31    0
# 22570     UU  1102  1076   1  452535200  12000   54    0
#
#                                                        d
# 415    [[-7.930359, -8.129578, -8.598328, -9.141296, ...
# 1470   [[-7.5015106, -7.1675262, -6.677292, -6.052292...
# 2525   [[-7.826599, -7.842224, -7.842224, -7.8480835,...
# 3580   [[-8.632759, -8.49604, -8.429634, -8.398384, -...
# 4635   [[-7.0348167, -7.7984886, -8.314114, -8.564114...
# 5690   [[-7.617279, -7.3907166, -7.2032166, -7.019623...
# 6745   [[-9.17131, -9.183029, -9.23967, -9.36467, -9....
# 7800   [[-2.9987183, -4.240906, -5.276062, -5.9518433...
# 8855   [[-10.04501, -9.943447, -9.912197, -9.867275, ...
# 9910   [[-5.060528, -5.3027153, -5.535137, -5.6640434...
# 10965  [[-7.9178925, -8.124924, -8.246017, -8.183517,...
# 12020  [[-5.1142616, -5.090824, -4.9560585, -4.913089...
# 13075  [[0.70633316, 0.028598785, -0.8678856, -1.3483...
# 14130  [[-1.2090034, -1.4023628, -1.8984566, -2.61134...
# 15185  [[-8.946899, -9.286743, -9.44104, -9.431274, -...
# 16240  [[-9.130035, -9.473785, -9.868317, -10.360504,...
# 17295  [[-10.897854, -10.936916, -10.667385, -10.1712...
# 18350  [[-5.656128, -5.7244873, -5.8963623, -6.117065...
# 19405  [[-6.307106, -6.3442154, -6.3930435, -6.422340...
# 20460  [[-0.9665451, -0.95482635, -2.1559982, -3.4997...
# 21515  [[-4.146324, -3.814293, -3.595543, -3.5389023,...
# 22570  [[-7.770569, -7.6104126, -7.7979126, -8.333069...

# %% [markdown]
# ## Performing simple calculations

# %% [markdown]
# ### Wind Modulus

# %% [markdown]
# ##### Create a record to hold the result

# %%
uv_df = vv_df.copy(deep=True)

# %% [markdown]
# ##### Get a fresh index starting from 0 and change the nomvar accordingly

# %%
uv_df = uv_df.reset_index(drop=True)
uv_df.loc[:,'nomvar']='UV'

# %% [markdown]
# ##### Get the first rows for uu and vv

# %%
uu = (uu_df.iloc[0]['d'])
vv = (vv_df.iloc[0]['d'])

# %% [markdown]
# #### the algorithm, after this uv_df contains our result for the wind modulus in knots

# %%
uv = (uu**2 + vv**2)**.5
# store the result in the dataframe
uv_df.at[0,'d'] = uv
print('UU\n',uu.compute())
print('VV\n',vv.compute())
# Out:
# UU
#  [[ -7.930359   -8.129578   -8.598328  ... -12.676453  -12.309265
#   -11.758484 ]
#  [ -8.133484   -8.289734   -8.688171  ... -12.582703  -12.281921
#   -11.805359 ]
#  [ -8.371765   -8.403015   -8.664734  ... -12.508484  -12.270203
#   -11.860046 ]
#  ...
#  [  1.3001099   1.8547974   2.304016  ...  -3.0475464  -2.8912964
#    -2.774109 ]
#  [  1.1672974   1.3743286   1.6790161 ...  -2.9850464  -2.789734
#    -2.711609 ]
#  [  1.2376099   1.3587036   1.4212036 ...  -2.9381714  -2.8483276
#    -2.8327026]]
# VV
#  [[13.310841   13.287403   13.607716   ... -8.306347   -8.552441
#   -9.007519  ]
#  [13.203419   13.1370125  13.428028   ... -8.3004875  -8.3786125
#   -8.704784  ]
#  [13.045216   12.904591   13.138966   ... -8.427441   -8.351269
#   -8.493847  ]
#  ...
#  [-1.0309563  -1.3180656  -1.2907219  ...  1.1194344   1.0237312
#    0.9280281 ]
#  [-0.90595627 -1.1149406  -1.1090813  ...  1.3362312   1.2444344
#    1.0549812 ]
#  [-0.8317375  -1.0368156  -1.0778313  ...  1.3792      1.3147469
#    1.1975594 ]]

# %% [markdown]
# #### Visualize dask operations

# %%
uv_df.iloc[0]['d'].visualize()

# %%
print('UV\n',uv_df.iloc[0]['d'].compute())
# Out:
# UV
#  [[15.494163  15.57707   16.09662   ... 15.155456  14.988737  14.812067 ]
#  [15.507541  15.533859  15.993632  ... 15.073901  14.867641  14.667644 ]
#  [15.500455  15.3993225 15.738806  ... 15.08257   14.84256   14.587876 ]
#  ...
#  [ 1.6592638  2.2754276  2.640919  ...  3.2466402  3.0671842  2.9252207]
#  [ 1.4776129  1.7697095  2.0122516 ...  3.2704763  3.0547066  2.9096062]
#  [ 1.4911289  1.7091116  1.7836872 ...  3.2457733  3.1371212  3.0754435]]

# %%
# internal structure of the dask array
uv_df.iloc[0]['d']
# Out:
# dask.array<pow, shape=(1102, 1076), dtype=float32, chunksize=(1102, 1076), chunktype=numpy.ndarray>

# %% [markdown]
# ### Wind Chill

# %%
tt_df = df.loc[(df.nomvar=="TT") & (df.surface==True)]

# %% [markdown]
# #### create a record to hold wind chill reseult and change the nomvar

# %%
re_df = uv_df.copy(deep=True)
re_df['nomvar']='RE'

# %% [markdown]
# #### the algorithm, after this re_df contains our result for the wind chill

# %%
tt = (tt_df.iloc[0]['d'])
uv = (uv_df.iloc[0]['d'])

# %%
# if (tt <= 0) & (uv >= 5) then
#    re = 13.12 + 0.6215 * tt + ( 0.3965 * tt - 11.37) * ( uv**0.16 )
# else
#    re = tt
re_df.at[0,'d'] = np.where( (tt <= 0) & (uv >= 5), 13.12 + 0.6215 * tt + ( 0.3965 * tt - 11.37) * ( uv**0.16 ), tt)
print('TT\n',tt.compute())
print('RE\n',re_df.iloc[0]['d'].compute())
# Out:
# TT
#  [[25.535908  25.430439  25.358173  ... 20.461689  20.403095  20.309345 ]
#  [25.489033  25.365986  25.272236  ... 20.377705  20.332783  20.280048 ]
#  [25.414814  25.26833   25.157001  ... 20.291767  20.246845  20.217548 ]
#  ...
#  [36.78786   36.983173  33.782     ...  3.727314   4.276142   4.6550484]
#  [35.848408  36.791767  36.20583   ...  3.5163765  4.0925484  4.350361 ]
#  [36.6238    35.91872   37.065205  ...  3.1511421  3.6530952  4.291767 ]]
# RE
#  [[25.535908  25.430439  25.358173  ... 20.461689  20.403095  20.309345 ]
#  [25.489033  25.365986  25.272236  ... 20.377705  20.332783  20.280048 ]
#  [25.414814  25.26833   25.157001  ... 20.291767  20.246845  20.217548 ]
#  ...
#  [36.78786   36.983173  33.782     ...  3.727314   4.276142   4.6550484]
#  [35.848408  36.791767  36.20583   ...  3.5163765  4.0925484  4.350361 ]
#  [36.6238    35.91872   37.065205  ...  3.1511421  3.6530952  4.291767 ]]

# %% [markdown]
# ### Basic statistics for TT records

# %% [markdown]
# #### Create a function to compute statistics

# %%
def compute_basic_stats(df:pd.DataFrame) -> pd.DataFrame:
    """ compute for each row in a datarfame, min, max, mean, standard_deviation and the 2d indice of min and max

    :param df: input dataframe
    :type df: pd.DataFrame
    :return: output dataframe with extra columns
    :rtype: pd.DataFrame
    """
    df = fstpy.compute(df)
    df['min']=None
    df['max']=None
    df['mean']=None
    df['std']=None
    df['min_pos']=None
    df['max_pos']=None
    for i in df.index:
        df.at[i,'mean'] = df.loc[i,'d'].mean()
        df.at[i,'std'] = df.loc[i,'d'].std()
        df.at[i,'min'] = df.loc[i,'d'].min()
        df.at[i,'max'] = df.loc[i,'d'].max()
        # index (i,j) of min in record
        df.at[i,'min_pos'] = np.unravel_index(df.at[i,'d'].argmin(), (df.at[i,'ni'],df.at[i,'nj']))
        df.at[i,'min_pos'] = (df.at[i,'min_pos'][0] + 1, df.at[i,'min_pos'][1]+1)
        # index (i,j) of max in record
        df.at[i,'max_pos'] = np.unravel_index(df.at[i,'d'].argmax(), (df.at[i,'ni'],df.at[i,'nj']))
        df.at[i,'max_pos'] = (df.at[i,'max_pos'][0] + 1, df.at[i,'max_pos'][1]+1)
    return df

# %%
new_df = compute_basic_stats(tt_df)
new_df
# Out:
#       nomvar typvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3  \
# 105       TT      P  R1_V710_N  1102  1076   1  452535200  12000   68    0
# 1160      TT      P  R1_V710_N  1102  1076   1  452535200  12000   32    0
# 2215      TT      P  R1_V710_N  1102  1076   1  452535200  12000   49    0
# 3270      TT      P  R1_V710_N  1102  1076   1  452535200  12000   55    0
# 4325      TT      P  R1_V710_N  1102  1076   1  452535200  12000   35    0
# 5380      TT      P  R1_V710_N  1102  1076   1  452535200  12000   14    0
# 6435      TT      P  R1_V710_N  1102  1076   1  452535200  12000   46    0
# 7490      TT      P  R1_V710_N  1102  1076   1  452535200  12000   23    0
# 8545      TT      P  R1_V710_N  1102  1076   1  452535200  12000   84    0
# 9600      TT      P  R1_V710_N  1102  1076   1  452535200  12000   16    0
# 10655     TT      P  R1_V710_N  1102  1076   1  452535200  12000   52    0
# 11710     TT      P  R1_V710_N  1102  1076   1  452535200  12000   17    0
# 12765     TT      P  R1_V710_N  1102  1076   1  452535200  12000   25    0
# 13820     TT      P  R1_V710_N  1102  1076   1  452535200  12000   80    0
# 14875     TT      P  R1_V710_N  1102  1076   1  452535200  12000   71    0
# 15930     TT      P  R1_V710_N  1102  1076   1  452535200  12000   67    0
# 16985     TT      P  R1_V710_N  1102  1076   1  452535200  12000   83    0
# 18040     TT      P  R1_V710_N  1102  1076   1  452535200  12000    4    0
# 19095     TT      P  R1_V710_N  1102  1076   1  452535200  12000   12    0
# 20150     TT      P  R1_V710_N  1102  1076   1  452535200  12000   62    0
# 21205     TT      P  R1_V710_N  1102  1076   1  452535200  12000   31    0
# 22260     TT      P  R1_V710_N  1102  1076   1  452535200  12000   54    0
#
#        ...  bounded  missing_data  ensemble_extra_info  vctype        min  \
# 105    ...    False         False                False     ETA  -31.35667
# 1160   ...    False         False                False     ETA -38.742432
# 2215   ...    False         False                False     ETA -37.669609
# 3270   ...    False         False                False     ETA -35.744144
# 4325   ...    False         False                False     ETA -37.927513
# 5380   ...    False         False                False     ETA -40.764553
# 6435   ...    False         False                False     ETA -36.320568
# 7490   ...    False         False                False     ETA -40.928642
# 8545   ...    False         False                False     ETA -32.304153
# 9600   ...    False         False                False     ETA -39.779816
# 10655  ...    False         False                False     ETA  -37.33379
# 11710  ...    False         False                False     ETA -39.145077
# 12765  ...    False         False                False     ETA -40.521233
# 13820  ...    False         False                False     ETA -33.139282
# 14875  ...    False         False                False     ETA -31.221581
# 15930  ...    False         False                False     ETA -31.251141
# 16985  ...    False         False                False     ETA -32.030922
# 18040  ...    False         False                False     ETA -43.248154
# 19095  ...    False         False                False     ETA -43.288342
# 20150  ...    False         False                False     ETA -30.715126
# 21205  ...    False         False                False     ETA -39.118862
# 22260  ...    False         False                False     ETA -36.188412
#
#              max       mean        std     min_pos      max_pos
# 105    37.963642   14.23567  12.197015  (799, 851)    (717, 87)
# 1160   30.341553  12.749607  12.178773  (433, 713)   (703, 101)
# 2215    33.58625  13.680307  12.032933  (894, 707)   (558, 115)
# 3270   31.224606  12.958476  11.918756  (894, 705)   (471, 273)
# 4325   29.945534  12.539001  12.208581  (433, 713)   (689, 105)
# 5380   33.618259  12.934836  12.278126  (807, 796)   (1024, 80)
# 6435   37.661854  14.103417  12.423443  (868, 763)    (687, 93)
# 7490   37.098701   14.00673  12.429061  (811, 799)   (623, 209)
# 8545   30.162643  12.800724  11.749433  (730, 786)   (1048, 92)
# 9600   35.593231  13.460595  12.428946  (809, 795)   (974, 141)
# 10655  31.789257  13.236539  11.915224  (893, 707)   (467, 279)
# 11710  37.163517  13.690438  12.498761  (808, 793)   (973, 141)
# 12765  33.834236  13.655102  12.158602  (814, 800)   (616, 177)
# 13820  30.640015  13.019399  11.705544  (900, 792)   (472, 274)
# 14875  36.913185  14.189188  11.988929  (799, 851)    (696, 92)
# 15930  37.719563  14.140656  12.184587  (799, 851)    (1101, 8)
# 16985  30.031578  12.806731   11.74488  (730, 786)  (1036, 133)
# 18040  30.892471   13.36894  12.081364  (809, 791)   (602, 204)
# 19095  29.971424  12.685672  12.191922  (806, 796)  (1077, 124)
# 20150  33.028038  12.944227  11.980693  (806, 849)   (1024, 81)
# 21205   30.55106  12.844222   12.15478  (433, 713)    (705, 99)
# 22260  31.532291  13.050107  11.909812  (894, 705)   (470, 275)
#
# [22 rows x 64 columns]

# %% [markdown]
# ### Basic statistics for each column of 3d matrix

# %%
tt3d_df = df.loc[(df.nomvar=='TT') & (df.ip2==12)]
# sort by level and reset index
tt3d_df = tt3d_df.sort_values(by='level',ascending=tt3d_df.iloc[0]['ascending']).reset_index(drop=True)
tt3d_df
# Out:
#    nomvar typvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3  ...  \
# 0      TT      P  R1_V710_N  1102  1076   1  452535200  12000   12    0  ...
# 1      TT      P  R1_V710_N  1102  1076   1  452535200  11975   12    0  ...
# 2      TT      P  R1_V710_N  1102  1076   1  452535200  11950   12    0  ...
# 3      TT      P  R1_V710_N  1102  1076   1  452535200  11900   12    0  ...
# 4      TT      P  R1_V710_N  1102  1076   1  452535200  11850   12    0  ...
# ..    ...    ...        ...   ...   ...  ..        ...    ...  ...  ...  ...
# 57     TT      P  R1_V710_N  1102  1076   1  452535200   2508   12    0  ...
# 58     TT      P  R1_V710_N  1102  1076   1  452535200   2374   12    0  ...
# 59     TT      P  R1_V710_N  1102  1076   1  452535200   2233   12    0  ...
# 60     TT      P  R1_V710_N  1102  1076   1  452535200   2102   12    0  ...
# 61     TT      P  R1_V710_N  1102  1076   1  452535200   2000   12    0  ...
#
#     interval  multiple_modifications  zapped  filtered interpolated  \
# 0       None                   False   False     False        False
# 1       None                   False   False     False        False
# 2       None                   False   False     False        False
# 3       None                   False   False     False        False
# 4       None                   False   False     False        False
# ..       ...                     ...     ...       ...          ...
# 57      None                   False   False     False        False
# 58      None                   False   False     False        False
# 59      None                   False   False     False        False
# 60      None                   False   False     False        False
# 61      None                   False   False     False        False
#
#     unit_converted  bounded  missing_data  ensemble_extra_info  vctype
# 0            False    False         False                False     ETA
# 1            False    False         False                False     ETA
# 2            False    False         False                False     ETA
# 3            False    False         False                False     ETA
# 4            False    False         False                False     ETA
# ..             ...      ...           ...                  ...     ...
# 57           False    False         False                False     ETA
# 58           False    False         False                False     ETA
# 59           False    False         False                False     ETA
# 60           False    False         False                False     ETA
# 61           False    False         False                False     ETA
#
# [62 rows x 58 columns]

# %% [markdown]
# #### Use an xarray for 3d operations

# %%
tt_ds = fstpy.to_cmc_xarray(tt3d_df)
tt_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (level: 62, y: 1076, x: 1102)
# Coordinates:
#   * level    (level) float32 1.0 0.9975 0.995 0.99 ... 0.0374 0.0233 0.0102 0.0
#   * y        (y) float32 -48.51 -48.42 -48.33 -48.24 ... 47.97 48.06 48.15 48.24
#   * x        (x) float32 126.9 127.0 127.1 127.2 ... 225.7 225.8 225.9 226.0
# Data variables:
#     TT       (level, x, y) float32 dask.array<chunksize=(1, 1102, 1076), meta=np.ndarray>

# %%
tt_ds.TT
# Out:
# <xarray.DataArray 'TT' (level: 62, x: 1102, y: 1076)>
# dask.array<stack, shape=(62, 1102, 1076), dtype=float32, chunksize=(1, 1102, 1076), chunktype=numpy.ndarray>
# Coordinates:
#   * level    (level) float32 1.0 0.9975 0.995 0.99 ... 0.0374 0.0233 0.0102 0.0
#   * y        (y) float32 -48.51 -48.42 -48.33 -48.24 ... 47.97 48.06 48.15 48.24
#   * x        (x) float32 126.9 127.0 127.1 127.2 ... 225.7 225.8 225.9 226.0

# %% [markdown]
# #### Compute the stats for each column

# %%
tt_min = tt_ds.TT.min(dim='level')
tt_max = tt_ds.TT.max(dim='level')
tt_std = tt_ds.TT.std(dim='level')
tt_mean = tt_ds.TT.mean(dim='level')

# %% [markdown]
# #### Create containers for our results

# %%
# creates a 1 row dataframe based on a model dataframe
def create_result_df(df:pd.DataFrame, nomvar:str, operation_name:str) ->  pd.DataFrame:
   res_df = pd.DataFrame([df.iloc[0].to_dict()])
   res_df['nomvar']=nomvar
   res_df['etiket']=operation_name
   return res_df

min_df = create_result_df(tt_df,'MIN','MINIMUM')
max_df = create_result_df(tt_df,'MAX','MAXIMUM')
std_df = create_result_df(tt_df,'STD','STDDEV')
mean_df = create_result_df(tt_df,'MEAN','AVERAGE')

# %% [markdown]
# #### assign resulting arrays to the dataframes

# %%
# .at gets the row at index in a dataframe, we have 1 row dataframes in each case and our arrays are simple 2d result arrays 
min_df.at[0,'d'] = tt_min.values
max_df.at[0,'d'] = tt_max.values 
std_df.at[0,'d'] = tt_std.values 
mean_df.at[0,'d'] = tt_mean.values

# %% [markdown]
# #### combine all results into a single dataframe

# %%
res_df = pd.concat([min_df,max_df,std_df,mean_df],ignore_index=True)
res_df[['nomvar','etiket','d']]
# Out:
#   nomvar   etiket                                                  d
# 0    MIN  MINIMUM  [[-75.87637, -75.90567, -75.94473, -75.99161, ...
# 1    MAX  MAXIMUM  [[23.69994, 24.217518, 24.682362, 24.891346, 2...
# 2    STD   STDDEV  [[37.454422, 37.546623, 37.630547, 37.688354, ...
# 3   MEAN  AVERAGE  [[-22.297424, -22.223946, -22.160772, -22.1176...

# %% [markdown]
# ### Grouping data

# %% [markdown]
# #### grouping data by grid, the usual case when you have multiple grids in a dataframe

# %%
grid_groups = df.groupby(by=['grid'])

for grid,grid_df in grid_groups:
    print(f'grid: {grid}')
    print(grid_df[['nomvar','etiket','ni','nj','nk','dateo','ip1','ip2','ip3']])
# Out:
# grid: 8608677806
#       nomvar     etiket    ni    nj  nk      dateo    ip1    ip2  ip3
# 0         >>  R1_V710_N  1102     1   1  408244400  86086  77806    1
# 1         ^^  R1_V710_N     1  1076   1  408244400  86086  77806    1
# 44        TT  R1_V710_N  1102  1076   1  452535200   2000     68    0
# 45        TT  R1_V710_N  1102  1076   1  452535200   2102     68    0
# 46        TT  R1_V710_N  1102  1076   1  452535200   2233     68    0
# ...      ...        ...   ...   ...  ..        ...    ...    ...  ...
# 26703     K1  R1_V710_N  1102  1076   1  452535200   1195     54    0
# 26704     K1  R1_V710_N  1102  1076   1  452535200   1196     54    0
# 26705     K1  R1_V710_N  1102  1076   1  452535200   1197     54    0
# 26706     K1  R1_V710_N  1102  1076   1  452535200   1198     54    0
# 26707     K1  R1_V710_N  1102  1076   1  452535200   1199     54    0
#
# [26666 rows x 9 columns]

# %% [markdown]
# #### grouping data by forecast hour, the usual case when you have multiple forecast hours per grid in a dataframe

# %%
forecast_hour_groups = df.loc[df.nomvar=='TT'].groupby(by=['grid','forecast_hour'])

for (grid,fhour),forecast_hour_df in forecast_hour_groups:
    print(f'grid: {grid} forecast_hour: {fhour}')
    print(forecast_hour_df.head(2)[['nomvar','etiket','ni','nj','nk','dateo','ip1','ip2','ip3']])
# Out:
# grid: 8608677806 forecast_hour: 0 days 04:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 17979     TT  R1_V710_N  1102  1076   1  452535200  2000    4    0
# 17980     TT  R1_V710_N  1102  1076   1  452535200  2102    4    0
# grid: 8608677806 forecast_hour: 0 days 12:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 19034     TT  R1_V710_N  1102  1076   1  452535200  2000   12    0
# 19035     TT  R1_V710_N  1102  1076   1  452535200  2102   12    0
# grid: 8608677806 forecast_hour: 0 days 14:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 5319     TT  R1_V710_N  1102  1076   1  452535200  2000   14    0
# 5320     TT  R1_V710_N  1102  1076   1  452535200  2102   14    0
# grid: 8608677806 forecast_hour: 0 days 16:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 9539     TT  R1_V710_N  1102  1076   1  452535200  2000   16    0
# 9540     TT  R1_V710_N  1102  1076   1  452535200  2102   16    0
# grid: 8608677806 forecast_hour: 0 days 17:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 11649     TT  R1_V710_N  1102  1076   1  452535200  2000   17    0
# 11650     TT  R1_V710_N  1102  1076   1  452535200  2102   17    0
# grid: 8608677806 forecast_hour: 0 days 23:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 7429     TT  R1_V710_N  1102  1076   1  452535200  2000   23    0
# 7430     TT  R1_V710_N  1102  1076   1  452535200  2102   23    0
# grid: 8608677806 forecast_hour: 1 days 01:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 12704     TT  R1_V710_N  1102  1076   1  452535200  2000   25    0
# 12705     TT  R1_V710_N  1102  1076   1  452535200  2102   25    0
# grid: 8608677806 forecast_hour: 1 days 07:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 21144     TT  R1_V710_N  1102  1076   1  452535200  2000   31    0
# 21145     TT  R1_V710_N  1102  1076   1  452535200  2102   31    0
# grid: 8608677806 forecast_hour: 1 days 08:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 1099     TT  R1_V710_N  1102  1076   1  452535200  2000   32    0
# 1100     TT  R1_V710_N  1102  1076   1  452535200  2102   32    0
# grid: 8608677806 forecast_hour: 1 days 11:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 4264     TT  R1_V710_N  1102  1076   1  452535200  2000   35    0
# 4265     TT  R1_V710_N  1102  1076   1  452535200  2102   35    0
# grid: 8608677806 forecast_hour: 1 days 22:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 6374     TT  R1_V710_N  1102  1076   1  452535200  2000   46    0
# 6375     TT  R1_V710_N  1102  1076   1  452535200  2102   46    0
# grid: 8608677806 forecast_hour: 2 days 01:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 2154     TT  R1_V710_N  1102  1076   1  452535200  2000   49    0
# 2155     TT  R1_V710_N  1102  1076   1  452535200  2102   49    0
# grid: 8608677806 forecast_hour: 2 days 04:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 10594     TT  R1_V710_N  1102  1076   1  452535200  2000   52    0
# 10595     TT  R1_V710_N  1102  1076   1  452535200  2102   52    0
# grid: 8608677806 forecast_hour: 2 days 06:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 22199     TT  R1_V710_N  1102  1076   1  452535200  2000   54    0
# 22200     TT  R1_V710_N  1102  1076   1  452535200  2102   54    0
# grid: 8608677806 forecast_hour: 2 days 07:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 3209     TT  R1_V710_N  1102  1076   1  452535200  2000   55    0
# 3210     TT  R1_V710_N  1102  1076   1  452535200  2102   55    0
# grid: 8608677806 forecast_hour: 2 days 14:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 20089     TT  R1_V710_N  1102  1076   1  452535200  2000   62    0
# 20090     TT  R1_V710_N  1102  1076   1  452535200  2102   62    0
# grid: 8608677806 forecast_hour: 2 days 19:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 15869     TT  R1_V710_N  1102  1076   1  452535200  2000   67    0
# 15870     TT  R1_V710_N  1102  1076   1  452535200  2102   67    0
# grid: 8608677806 forecast_hour: 2 days 20:00:00
#    nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 44     TT  R1_V710_N  1102  1076   1  452535200  2000   68    0
# 45     TT  R1_V710_N  1102  1076   1  452535200  2102   68    0
# grid: 8608677806 forecast_hour: 2 days 23:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 14814     TT  R1_V710_N  1102  1076   1  452535200  2000   71    0
# 14815     TT  R1_V710_N  1102  1076   1  452535200  2102   71    0
# grid: 8608677806 forecast_hour: 3 days 08:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 13759     TT  R1_V710_N  1102  1076   1  452535200  2000   80    0
# 13760     TT  R1_V710_N  1102  1076   1  452535200  2102   80    0
# grid: 8608677806 forecast_hour: 3 days 11:00:00
#       nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 16924     TT  R1_V710_N  1102  1076   1  452535200  2000   83    0
# 16925     TT  R1_V710_N  1102  1076   1  452535200  2102   83    0
# grid: 8608677806 forecast_hour: 3 days 12:00:00
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 8484     TT  R1_V710_N  1102  1076   1  452535200  2000   84    0
# 8485     TT  R1_V710_N  1102  1076   1  452535200  2102   84    0

# %% [markdown]
# #### grouping data by level, the usual case when you have multiple levels per grid in a dataframe

# %%
levels_groups = df.loc[df.nomvar=='UU'].groupby(by=['grid','level'])

for (grid,level),level_df in levels_groups:
    print(f'grid: {grid} level: {level}')
    print(level_df.head(2)[['nomvar','etiket','ni','nj','nk','dateo','ip1','ip2','ip3']])
# Out:
# grid: 8608677806 level: 0.0
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 354      UU  R1_V710_N  1102  1076   1  452535200  2000   68    0
# 1409     UU  R1_V710_N  1102  1076   1  452535200  2000   32    0
# grid: 8608677806 level: 0.010200000368058681
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 355      UU  R1_V710_N  1102  1076   1  452535200  2102   68    0
# 1410     UU  R1_V710_N  1102  1076   1  452535200  2102   32    0
# grid: 8608677806 level: 0.02329999953508377
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 356      UU  R1_V710_N  1102  1076   1  452535200  2233   68    0
# 1411     UU  R1_V710_N  1102  1076   1  452535200  2233   32    0
# grid: 8608677806 level: 0.03739999979734421
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 357      UU  R1_V710_N  1102  1076   1  452535200  2374   68    0
# 1412     UU  R1_V710_N  1102  1076   1  452535200  2374   32    0
# grid: 8608677806 level: 0.05079999938607216
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 358      UU  R1_V710_N  1102  1076   1  452535200  2508   68    0
# 1413     UU  R1_V710_N  1102  1076   1  452535200  2508   32    0
# grid: 8608677806 level: 0.0625
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 359      UU  R1_V710_N  1102  1076   1  452535200  2625   68    0
# 1414     UU  R1_V710_N  1102  1076   1  452535200  2625   32    0
# grid: 8608677806 level: 0.07199999690055847
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 360      UU  R1_V710_N  1102  1076   1  452535200  2720   68    0
# 1415     UU  R1_V710_N  1102  1076   1  452535200  2720   32    0
# grid: 8608677806 level: 0.0794999971985817
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 361      UU  R1_V710_N  1102  1076   1  452535200  2795   68    0
# 1416     UU  R1_V710_N  1102  1076   1  452535200  2795   32    0
# grid: 8608677806 level: 0.0851999968290329
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 362      UU  R1_V710_N  1102  1076   1  452535200  2852   68    0
# 1417     UU  R1_V710_N  1102  1076   1  452535200  2852   32    0
# grid: 8608677806 level: 0.08969999849796295
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 363      UU  R1_V710_N  1102  1076   1  452535200  2897   68    0
# 1418     UU  R1_V710_N  1102  1076   1  452535200  2897   32    0
# grid: 8608677806 level: 0.0940999984741211
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 364      UU  R1_V710_N  1102  1076   1  452535200  2941   68    0
# 1419     UU  R1_V710_N  1102  1076   1  452535200  2941   32    0
# grid: 8608677806 level: 0.0989999994635582
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 365      UU  R1_V710_N  1102  1076   1  452535200  2990   68    0
# 1420     UU  R1_V710_N  1102  1076   1  452535200  2990   32    0
# grid: 8608677806 level: 0.10440000146627426
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 366      UU  R1_V710_N  1102  1076   1  452535200  3044   68    0
# 1421     UU  R1_V710_N  1102  1076   1  452535200  3044   32    0
# grid: 8608677806 level: 0.1103999987244606
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 367      UU  R1_V710_N  1102  1076   1  452535200  3104   68    0
# 1422     UU  R1_V710_N  1102  1076   1  452535200  3104   32    0
# grid: 8608677806 level: 0.11720000207424164
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 368      UU  R1_V710_N  1102  1076   1  452535200  3172   68    0
# 1423     UU  R1_V710_N  1102  1076   1  452535200  3172   32    0
# grid: 8608677806 level: 0.12479999661445618
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 369      UU  R1_V710_N  1102  1076   1  452535200  3248   68    0
# 1424     UU  R1_V710_N  1102  1076   1  452535200  3248   32    0
# grid: 8608677806 level: 0.13339999318122864
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 370      UU  R1_V710_N  1102  1076   1  452535200  3334   68    0
# 1425     UU  R1_V710_N  1102  1076   1  452535200  3334   32    0
# grid: 8608677806 level: 0.14309999346733093
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 371      UU  R1_V710_N  1102  1076   1  452535200  3431   68    0
# 1426     UU  R1_V710_N  1102  1076   1  452535200  3431   32    0
# grid: 8608677806 level: 0.15410000085830688
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 372      UU  R1_V710_N  1102  1076   1  452535200  3541   68    0
# 1427     UU  R1_V710_N  1102  1076   1  452535200  3541   32    0
# grid: 8608677806 level: 0.16670000553131104
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 373      UU  R1_V710_N  1102  1076   1  452535200  3667   68    0
# 1428     UU  R1_V710_N  1102  1076   1  452535200  3667   32    0
# grid: 8608677806 level: 0.18119999766349792
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 374      UU  R1_V710_N  1102  1076   1  452535200  3812   68    0
# 1429     UU  R1_V710_N  1102  1076   1  452535200  3812   32    0
# grid: 8608677806 level: 0.19760000705718994
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 375      UU  R1_V710_N  1102  1076   1  452535200  3976   68    0
# 1430     UU  R1_V710_N  1102  1076   1  452535200  3976   32    0
# grid: 8608677806 level: 0.21490000188350677
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 376      UU  R1_V710_N  1102  1076   1  452535200  4149   68    0
# 1431     UU  R1_V710_N  1102  1076   1  452535200  4149   32    0
# grid: 8608677806 level: 0.23309999704360962
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 377      UU  R1_V710_N  1102  1076   1  452535200  4331   68    0
# 1432     UU  R1_V710_N  1102  1076   1  452535200  4331   32    0
# grid: 8608677806 level: 0.25220000743865967
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 378      UU  R1_V710_N  1102  1076   1  452535200  4522   68    0
# 1433     UU  R1_V710_N  1102  1076   1  452535200  4522   32    0
# grid: 8608677806 level: 0.2721000015735626
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 379      UU  R1_V710_N  1102  1076   1  452535200  4721   68    0
# 1434     UU  R1_V710_N  1102  1076   1  452535200  4721   32    0
# grid: 8608677806 level: 0.29280000925064087
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 380      UU  R1_V710_N  1102  1076   1  452535200  4928   68    0
# 1435     UU  R1_V710_N  1102  1076   1  452535200  4928   32    0
# grid: 8608677806 level: 0.31439998745918274
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 381      UU  R1_V710_N  1102  1076   1  452535200  5144   68    0
# 1436     UU  R1_V710_N  1102  1076   1  452535200  5144   32    0
# grid: 8608677806 level: 0.336899995803833
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 382      UU  R1_V710_N  1102  1076   1  452535200  5369   68    0
# 1437     UU  R1_V710_N  1102  1076   1  452535200  5369   32    0
# grid: 8608677806 level: 0.3601999878883362
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 383      UU  R1_V710_N  1102  1076   1  452535200  5602   68    0
# 1438     UU  R1_V710_N  1102  1076   1  452535200  5602   32    0
# grid: 8608677806 level: 0.38429999351501465
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 384      UU  R1_V710_N  1102  1076   1  452535200  5843   68    0
# 1439     UU  R1_V710_N  1102  1076   1  452535200  5843   32    0
# grid: 8608677806 level: 0.4090999960899353
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 385      UU  R1_V710_N  1102  1076   1  452535200  6091   68    0
# 1440     UU  R1_V710_N  1102  1076   1  452535200  6091   32    0
# grid: 8608677806 level: 0.43479999899864197
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 386      UU  R1_V710_N  1102  1076   1  452535200  6348   68    0
# 1441     UU  R1_V710_N  1102  1076   1  452535200  6348   32    0
# grid: 8608677806 level: 0.4611999988555908
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 387      UU  R1_V710_N  1102  1076   1  452535200  6612   68    0
# 1442     UU  R1_V710_N  1102  1076   1  452535200  6612   32    0
# grid: 8608677806 level: 0.48829999566078186
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 388      UU  R1_V710_N  1102  1076   1  452535200  6883   68    0
# 1443     UU  R1_V710_N  1102  1076   1  452535200  6883   32    0
# grid: 8608677806 level: 0.5160999894142151
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 389      UU  R1_V710_N  1102  1076   1  452535200  7161   68    0
# 1444     UU  R1_V710_N  1102  1076   1  452535200  7161   32    0
# grid: 8608677806 level: 0.5446000099182129
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 390      UU  R1_V710_N  1102  1076   1  452535200  7446   68    0
# 1445     UU  R1_V710_N  1102  1076   1  452535200  7446   32    0
# grid: 8608677806 level: 0.5737000107765198
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 391      UU  R1_V710_N  1102  1076   1  452535200  7737   68    0
# 1446     UU  R1_V710_N  1102  1076   1  452535200  7737   32    0
# grid: 8608677806 level: 0.6033999919891357
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 392      UU  R1_V710_N  1102  1076   1  452535200  8034   68    0
# 1447     UU  R1_V710_N  1102  1076   1  452535200  8034   32    0
# grid: 8608677806 level: 0.6337000131607056
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 393      UU  R1_V710_N  1102  1076   1  452535200  8337   68    0
# 1448     UU  R1_V710_N  1102  1076   1  452535200  8337   32    0
# grid: 8608677806 level: 0.6646000146865845
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 394      UU  R1_V710_N  1102  1076   1  452535200  8646   68    0
# 1449     UU  R1_V710_N  1102  1076   1  452535200  8646   32    0
# grid: 8608677806 level: 0.695900022983551
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 395      UU  R1_V710_N  1102  1076   1  452535200  8959   68    0
# 1450     UU  R1_V710_N  1102  1076   1  452535200  8959   32    0
# grid: 8608677806 level: 0.7271999716758728
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 396      UU  R1_V710_N  1102  1076   1  452535200  9272   68    0
# 1451     UU  R1_V710_N  1102  1076   1  452535200  9272   32    0
# grid: 8608677806 level: 0.7566999793052673
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 397      UU  R1_V710_N  1102  1076   1  452535200  9567   68    0
# 1452     UU  R1_V710_N  1102  1076   1  452535200  9567   32    0
# grid: 8608677806 level: 0.784500002861023
#      nomvar     etiket    ni    nj  nk      dateo   ip1  ip2  ip3
# 398      UU  R1_V710_N  1102  1076   1  452535200  9845   68    0
# 1453     UU  R1_V710_N  1102  1076   1  452535200  9845   32    0
# grid: 8608677806 level: 0.8104000091552734
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 399      UU  R1_V710_N  1102  1076   1  452535200  10104   68    0
# 1454     UU  R1_V710_N  1102  1076   1  452535200  10104   32    0
# grid: 8608677806 level: 0.8345999717712402
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 400      UU  R1_V710_N  1102  1076   1  452535200  10346   68    0
# 1455     UU  R1_V710_N  1102  1076   1  452535200  10346   32    0
# grid: 8608677806 level: 0.8571000099182129
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 401      UU  R1_V710_N  1102  1076   1  452535200  10571   68    0
# 1456     UU  R1_V710_N  1102  1076   1  452535200  10571   32    0
# grid: 8608677806 level: 0.878000020980835
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 402      UU  R1_V710_N  1102  1076   1  452535200  10780   68    0
# 1457     UU  R1_V710_N  1102  1076   1  452535200  10780   32    0
# grid: 8608677806 level: 0.8973000049591064
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 403      UU  R1_V710_N  1102  1076   1  452535200  10973   68    0
# 1458     UU  R1_V710_N  1102  1076   1  452535200  10973   32    0
# grid: 8608677806 level: 0.9150999784469604
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 404      UU  R1_V710_N  1102  1076   1  452535200  11151   68    0
# 1459     UU  R1_V710_N  1102  1076   1  452535200  11151   32    0
# grid: 8608677806 level: 0.9315999746322632
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 405      UU  R1_V710_N  1102  1076   1  452535200  11316   68    0
# 1460     UU  R1_V710_N  1102  1076   1  452535200  11316   32    0
# grid: 8608677806 level: 0.9466999769210815
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 406      UU  R1_V710_N  1102  1076   1  452535200  11467   68    0
# 1461     UU  R1_V710_N  1102  1076   1  452535200  11467   32    0
# grid: 8608677806 level: 0.9606000185012817
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 407      UU  R1_V710_N  1102  1076   1  452535200  11606   68    0
# 1462     UU  R1_V710_N  1102  1076   1  452535200  11606   32    0
# grid: 8608677806 level: 0.9670000076293945
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 408      UU  R1_V710_N  1102  1076   1  452535200  11670   68    0
# 1463     UU  R1_V710_N  1102  1076   1  452535200  11670   32    0
# grid: 8608677806 level: 0.9732999801635742
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 409      UU  R1_V710_N  1102  1076   1  452535200  11733   68    0
# 1464     UU  R1_V710_N  1102  1076   1  452535200  11733   32    0
# grid: 8608677806 level: 0.979200005531311
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 410      UU  R1_V710_N  1102  1076   1  452535200  11792   68    0
# 1465     UU  R1_V710_N  1102  1076   1  452535200  11792   32    0
# grid: 8608677806 level: 0.9850000143051147
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 411      UU  R1_V710_N  1102  1076   1  452535200  11850   68    0
# 1466     UU  R1_V710_N  1102  1076   1  452535200  11850   32    0
# grid: 8608677806 level: 0.9900000095367432
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 412      UU  R1_V710_N  1102  1076   1  452535200  11900   68    0
# 1467     UU  R1_V710_N  1102  1076   1  452535200  11900   32    0
# grid: 8608677806 level: 0.9950000047683716
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 413      UU  R1_V710_N  1102  1076   1  452535200  11950   68    0
# 1468     UU  R1_V710_N  1102  1076   1  452535200  11950   32    0
# grid: 8608677806 level: 0.9975000023841858
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 414      UU  R1_V710_N  1102  1076   1  452535200  11975   68    0
# 1469     UU  R1_V710_N  1102  1076   1  452535200  11975   32    0
# grid: 8608677806 level: 1.0
#      nomvar     etiket    ni    nj  nk      dateo    ip1  ip2  ip3
# 415      UU  R1_V710_N  1102  1076   1  452535200  12000   68    0
# 1470     UU  R1_V710_N  1102  1076   1  452535200  12000   32    0

# %% [markdown]
# ### Exporting the data

# %% [markdown]
# #### To standardfile

# %%
from os import getenv
import fstpy.all as fstpy
df = fstpy.StandardFileReader('/fs/site4/eccc/cmd/w/sbf000/fstpy/source_data_5005.std').to_pandas()
tt_df = df.loc[df.nomvar=='TT']
user = getenv("USER")
file = f'/tmp/{user}/TT.std'
fstpy.delete_file(file)
fstpy.StandardFileWriter(file, tt_df).to_fst()

# %% [markdown]
# #### Check the file

# %%
df = fstpy.StandardFileReader(file).to_pandas()
cols = list(df.columns)
cols.remove('d')
df[cols]
# Out:
#    nomvar typvar     etiket    ni    nj  nk      dateo       ip1    ip2  ip3  \
# 0      TT      P  R1_V710_N  1108  1082   1  442998800  76696048      6    0
# 1      TT      P  R1_V710_N  1108  1082   1  442998800  95178882      6    0
# 2      TT      P  R1_V710_N  1108  1082   1  442998800  95154915      6    0
# 3      TT      P  R1_V710_N  1108  1082   1  442998800  95529009      6    0
# 4      TT      P  R1_V710_N  1108  1082   1  442998800  97351772      6    0
# ..    ...    ...        ...   ...   ...  ..        ...       ...    ...  ...
# 84     TT      P  R1_V710_N  1108  1082   1  442998800  95201625      6    0
# 85     ^^      X  R1_V710_N     1  1082   1  442998800     33792  77761    1
# 86     >>      X  R1_V710_N  1108     1   1  442998800     33792  77761    1
# 87     P0      P  R1_V710_N  1108  1082   1  442998800         0      6    0
# 88     !!      X  R1_V710_N     3   175   1          0     33792  77761    0
#
#     ...    ig1    ig2    ig3    ig4      datev    key                path  \
# 0   ...  33792  77761      1      0  443004200      3  /tmp/sbf000/TT.std
# 1   ...  33792  77761      1      0  443004200   1027  /tmp/sbf000/TT.std
# 2   ...  33792  77761      1      0  443004200   2051  /tmp/sbf000/TT.std
# 3   ...  33792  77761      1      0  443004200   3075  /tmp/sbf000/TT.std
# 4   ...  33792  77761      1      0  443004200   4099  /tmp/sbf000/TT.std
# ..  ...    ...    ...    ...    ...        ...    ...                 ...
# 84  ...  33792  77761      1      0  443004200  86019  /tmp/sbf000/TT.std
# 85  ...   1470    560  54400  46560  442998800  87043  /tmp/sbf000/TT.std
# 86  ...   1470    560  54400  46560  442998800  88067  /tmp/sbf000/TT.std
# 87  ...  33792  77761      1      0  443004200  89091  /tmp/sbf000/TT.std
# 88  ...   5005      0    300   1500          0  90115  /tmp/sbf000/TT.std
#
#     file_modification_time         shape        grid
# 0      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 1      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 2      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 3      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 4      2021-09-29 11:41:45  (1108, 1082)  3379277761
# ..                     ...           ...         ...
# 84     2021-09-29 11:41:45  (1108, 1082)  3379277761
# 85     2021-09-29 11:41:45     (1, 1082)  3379277761
# 86     2021-09-29 11:41:45     (1108, 1)  3379277761
# 87     2021-09-29 11:41:45  (1108, 1082)  3379277761
# 88     2021-09-29 11:41:45      (3, 175)  3379277761
#
# [89 rows x 25 columns]

# %% [markdown]
# #### To pickle

# %%
pickle_file = f'/tmp/{user}/pickle_data.pkl.bz2'
fstpy.delete_file(pickle_file)
df.to_pickle(pickle_file)

# %% [markdown]
# #### Check the file

# %%
df = pd.read_pickle(pickle_file)
df
# Out:
#    nomvar typvar     etiket    ni    nj  nk      dateo       ip1    ip2  ip3  \
# 0      TT      P  R1_V710_N  1108  1082   1  442998800  76696048      6    0
# 1      TT      P  R1_V710_N  1108  1082   1  442998800  95178882      6    0
# 2      TT      P  R1_V710_N  1108  1082   1  442998800  95154915      6    0
# 3      TT      P  R1_V710_N  1108  1082   1  442998800  95529009      6    0
# 4      TT      P  R1_V710_N  1108  1082   1  442998800  97351772      6    0
# ..    ...    ...        ...   ...   ...  ..        ...       ...    ...  ...
# 84     TT      P  R1_V710_N  1108  1082   1  442998800  95201625      6    0
# 85     ^^      X  R1_V710_N     1  1082   1  442998800     33792  77761    1
# 86     >>      X  R1_V710_N  1108     1   1  442998800     33792  77761    1
# 87     P0      P  R1_V710_N  1108  1082   1  442998800         0      6    0
# 88     !!      X  R1_V710_N     3   175   1          0     33792  77761    0
#
#     ...    ig2    ig3    ig4      datev    key                path  \
# 0   ...  77761      1      0  443004200      3  /tmp/sbf000/TT.std
# 1   ...  77761      1      0  443004200   1027  /tmp/sbf000/TT.std
# 2   ...  77761      1      0  443004200   2051  /tmp/sbf000/TT.std
# 3   ...  77761      1      0  443004200   3075  /tmp/sbf000/TT.std
# 4   ...  77761      1      0  443004200   4099  /tmp/sbf000/TT.std
# ..  ...    ...    ...    ...        ...    ...                 ...
# 84  ...  77761      1      0  443004200  86019  /tmp/sbf000/TT.std
# 85  ...    560  54400  46560  442998800  87043  /tmp/sbf000/TT.std
# 86  ...    560  54400  46560  442998800  88067  /tmp/sbf000/TT.std
# 87  ...  77761      1      0  443004200  89091  /tmp/sbf000/TT.std
# 88  ...      0    300   1500          0  90115  /tmp/sbf000/TT.std
#
#     file_modification_time         shape        grid  \
# 0      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 1      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 2      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 3      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 4      2021-09-29 11:41:45  (1108, 1082)  3379277761
# ..                     ...           ...         ...
# 84     2021-09-29 11:41:45  (1108, 1082)  3379277761
# 85     2021-09-29 11:41:45     (1, 1082)  3379277761
# 86     2021-09-29 11:41:45     (1108, 1)  3379277761
# 87     2021-09-29 11:41:45  (1108, 1082)  3379277761
# 88     2021-09-29 11:41:45      (3, 175)  3379277761
#
#                                                     d
# 0   [[dask.array<getitem, shape=(), dtype=float32,...
# 1   [[dask.array<getitem, shape=(), dtype=float32,...
# 2   [[dask.array<getitem, shape=(), dtype=float32,...
# 3   [[dask.array<getitem, shape=(), dtype=float32,...
# 4   [[dask.array<getitem, shape=(), dtype=float32,...
# ..                                                ...
# 84  [[dask.array<getitem, shape=(), dtype=float32,...
# 85  [[dask.array<getitem, shape=(), dtype=float32,...
# 86  [[dask.array<getitem, shape=(), dtype=float32,...
# 87  [[dask.array<getitem, shape=(), dtype=float32,...
# 88  [[dask.array<getitem, shape=(), dtype=float64,...
#
# [89 rows x 26 columns]

# %%
df = fstpy.compute(df)
df
# Out:
#    nomvar typvar     etiket    ni    nj  nk      dateo       ip1    ip2  ip3  \
# 0      TT      P  R1_V710_N  1108  1082   1  442998800  76696048      6    0
# 1      TT      P  R1_V710_N  1108  1082   1  442998800  95178882      6    0
# 2      TT      P  R1_V710_N  1108  1082   1  442998800  95154915      6    0
# 3      TT      P  R1_V710_N  1108  1082   1  442998800  95529009      6    0
# 4      TT      P  R1_V710_N  1108  1082   1  442998800  97351772      6    0
# ..    ...    ...        ...   ...   ...  ..        ...       ...    ...  ...
# 84     TT      P  R1_V710_N  1108  1082   1  442998800  95201625      6    0
# 85     ^^      X  R1_V710_N     1  1082   1  442998800     33792  77761    1
# 86     >>      X  R1_V710_N  1108     1   1  442998800     33792  77761    1
# 87     P0      P  R1_V710_N  1108  1082   1  442998800         0      6    0
# 88     !!      X  R1_V710_N     3   175   1          0     33792  77761    0
#
#     ...    ig2    ig3    ig4      datev    key                path  \
# 0   ...  77761      1      0  443004200      3  /tmp/sbf000/TT.std
# 1   ...  77761      1      0  443004200   1027  /tmp/sbf000/TT.std
# 2   ...  77761      1      0  443004200   2051  /tmp/sbf000/TT.std
# 3   ...  77761      1      0  443004200   3075  /tmp/sbf000/TT.std
# 4   ...  77761      1      0  443004200   4099  /tmp/sbf000/TT.std
# ..  ...    ...    ...    ...        ...    ...                 ...
# 84  ...  77761      1      0  443004200  86019  /tmp/sbf000/TT.std
# 85  ...    560  54400  46560  442998800  87043  /tmp/sbf000/TT.std
# 86  ...    560  54400  46560  442998800  88067  /tmp/sbf000/TT.std
# 87  ...  77761      1      0  443004200  89091  /tmp/sbf000/TT.std
# 88  ...      0    300   1500          0  90115  /tmp/sbf000/TT.std
#
#     file_modification_time         shape        grid  \
# 0      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 1      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 2      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 3      2021-09-29 11:41:45  (1108, 1082)  3379277761
# 4      2021-09-29 11:41:45  (1108, 1082)  3379277761
# ..                     ...           ...         ...
# 84     2021-09-29 11:41:45  (1108, 1082)  3379277761
# 85     2021-09-29 11:41:45     (1, 1082)  3379277761
# 86     2021-09-29 11:41:45     (1108, 1)  3379277761
# 87     2021-09-29 11:41:45  (1108, 1082)  3379277761
# 88     2021-09-29 11:41:45      (3, 175)  3379277761
#
#                                                     d
# 0   [[26.068878, 26.084503, 26.108917, 26.167511, ...
# 1   [[15.86026, 15.958893, 16.014557, 16.121979, 1...
# 2   [[14.96785, 15.049881, 15.1201935, 15.15535, 1...
# 3   [[-43.06671, -43.033997, -43.00226, -42.972473...
# 4   [[-41.939545, -41.942474, -41.94687, -41.95077...
# ..                                                ...
# 84  [[15.393723, 15.270676, 15.173996, 15.044113, ...
# 85  [[-48.78, -48.690002, -48.600002, -48.510002, ...
# 86  [126.63, 126.71999, 126.81, 126.899994, 126.99...
# 87  [[1013.65466, 1013.63904, 1013.6078, 1013.5687...
# 88  [[5.0, -9999.0, 15.0, 97618941.0, 97680343.0, ...
#
# [89 rows x 26 columns]
